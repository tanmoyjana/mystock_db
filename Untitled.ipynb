# %%
from sqlalchemy_utils import database_exists, create_database, drop_database
from sqlalchemy import create_engine

# %%
import pandas as pd
data1 = pd.read_csv('data/bse-stock-list.csv', sep=',')
data2 = pd.read_csv('data/nse-stock-list.csv', sep=',')

# %%
x = "User(username='{self.username}', " \
"email_address='{self.email_address}', " \
"phone='{self.phone}', " \
"password='{self.password}')"

# %%
s1 = pd.merge(data1, data2, how='inner', on=['Co_Name'])

# %%
s1.duplicated('Co_Name')[0] == False
# Out:
# True

# %%
for i in range(0, len(s1)):
    if s1.duplicated('Co_Name')[i] == True:
        print i
# Out:
# 79
# 122

# %%
s1['Co_Name'][122]
# Out:
# 'eClerx Services'

# %%
data = s1.drop_duplicates(subset=['Co_Name', 'NSE_Symbol'], keep='first')

# %%
data['Co_Name']
# Out:
# 0              3M India
# 1        63 Moons Tech.
# 2                 A B B
# 3           Aarti Inds.
# 4         Aban Offshore
# 5          ABG Shipyard
# 6                   ACC
# 7           Adani Ports
# 8           Adani Power
# 9        Adlabs Entert.
# 10     Agro Tech Foods.
# 11            AIA Engg.
# 12        Ajanta Pharma
# 13           Akzo Nobel
# 14       Alembic Pharma
# 15       Allahabad Bank
# 16     Allcargo Logist.
# 17           Alok Inds.
# 18     Amara Raja Batt.
# 19          Ambuja Cem.
# 20           Amtek Auto
# 21            Anant Raj
# 22          Andhra Bank
# 23           Apar Inds.
# 24     Apollo Hospitals
# 25         Apollo Tyres
# 26           Arvind Ltd
# 27     Asahi India Glas
# 28        Ashok Leyland
# 29      Ashoka Buildcon
#              ...
# 468    United Breweries
# 469      United Spirits
# 470                 UPL
# 471         Usha Martin
# 472         Uttam Galva
# 473         V I P Inds.
# 474       Va Tech Wabag
# ...

# %%
df = pd.DataFrame({"A":["foo", "foo", "foo", "bar"], "B":[0,1,1,1], "C":["A","A","B","A"]})
data = df.drop_duplicates(subset=['A', 'C'], keep=False)

# %%
a = data.reset_index()

# %%
df.duplicated(['A', 'C'])
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
dir(pd.DataFrame)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
# ...

# %%
a['index']
# Out:
# 0    2
# 1    3
# Name: index, dtype: int64
